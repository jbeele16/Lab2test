# %% [markdown]
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://github.com/jbeele16/Lab2test
# )

# %%
# !pip install leafmap

# %%
import leafmap

# %%
m = leafmap.Map()
m
